# %% [markdown]
# <a href="https://colab.research.google.com/github/Thorne-Musau/np/blob/main/Aggregations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Summing the Values in an Array
import numpy as np

# %%
# Conventional way of doing it
L = np.random.random(100)
sum(L)
# Out:
# 47.99056275905056

# %%
# Numpy sum function- It is faster than the python's way
# It is not the same with sum function of python such that:
# np.sum is aware of multiple array dimensions
# %timeit np.sum(L)
# Out:
# 4.94 µs ± 1.36 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
big_array = np.random.rand(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 99 ms ± 418 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 528 µs ± 114 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Minimum and maximum - Python's way
min(big_array), max(big_array)
# Out:
# (5.610821197654658e-07, 0.9999991794919125)

# %%
# Use of the np.(min,max) functions
np.max(big_array), np.min(big_array)
# Out:
# (0.9999991794919125, 5.610821197654658e-07)

# %%
# Multi dimensional aggregates
M = np.random.random((3, 4))
M.sum()
# Out:
# 5.886276178622611

# %%
M.min(axis=0)
# Out:
# array([0.25797682, 0.308934  , 0.49281959, 0.07520906])

# %%
# Additional agg. functions(nan-Not a Number Version)
# np.sum	np.nansum-	Compute sum of elements
# np.prod	np.nanprod-Compute product of elements
# np.mean	np.nanmean- Compute mean of elements
# np.std	np.nanstd- Compute standard deviation
# np.var	np.nanvar- Compute variance
# np.min	np.nanmin- Find minimum value
# np.max	np.nanmax- Find maximum value
# np.argmin	np.nanargmin- Find index of minimum value
# np.argmax	np.nanargmax- Find index of maximum value
# np.median	np.nanmedian- Compute median of elements
# np.percentile	np.nanpercentile-	Compute rank-based statistics of elements
# np.any	N/A	Evaluate whether any elements are true
# np.all	N/A	Evaluate whether all elements are true

# %% [markdown]
# Aggregation Example

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls 'drive/My Drive/Dataset/weight-height.csv'
# Out:
# 'drive/My Drive/Dataset/weight-height.csv'

# %%
dataset = pd.read_csv('drive/My Drive/Dataset/weight-height.csv')
df =dataset.copy()
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Height'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %%
heights = np.array(df['Height'])

# %%
print("Mean height:       ", heights.mean())
print("Standard deviation:", heights.std())
print("Minimum height:    ", heights.min())
print("Maximum height:    ", heights.max())
# Out:
# Mean height:        66.36755975482124
# Standard deviation: 3.84733573955754
# Minimum height:     54.2631333250971
# Maximum height:     78.9987423463896

# %%
print("25th percentile:   ", np.percentile(heights, 25))
print("Median:            ", np.median(heights))
print("75th percentile:   ", np.percentile(heights, 75))
# Out:
# 25th percentile:    63.505620481218955
# Median:             66.31807008178464
# 75th percentile:    69.1742617268347
